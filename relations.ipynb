# %%
rels_str = "[ e^2, a^3, b^-2*c^2, b^4, (b^-1*d)^2, (c*a)^2, (b^-1*d^-1)^2, d^4,   d^-1*b^-2*a*d*a, c*a*e*a^-1*c^-1*e, d^-1*e*d^2*e*d^-1, e*b^2*e*b^-2,   (c*d^-1)^3, (e*a^-1)^3, c^-1*d^-2*a*d^-2*c^-1*a, (d*e)^2*(d^-1*e)^2,   (b^-1*a^-1*b^-1*a)^2, a*c^2*a^-1*e*c^-1*a^-1*c*a^-1*e,   c^-1*d^-1*c^-1*d*e*d^-1*c^-1*e*d*c^-1*e,   b*c*d*c^-1*b*c*b*d^-1*c^-1*d^-1*b^-1*c^-1,   b^-1*c^-1*d^-1*e*d*c^-1*b*c^-1*d^-1*e*d*c^-1, b^3*d*c*d*b^-2*d^-1*c*b^-1*d,   d^-2*c*b^-1*a^-1*b*c^-1*a*b^-1*c^-1*b^-1*a,   d^-1*e*d^-1*a*e*a^-1*d*e*d*a*e*a^-1, d*b^-1*a*d^-1*c*b^-1*a*b*a*c^-1*b*c,   d*e*d^-1*e*a*c*d*e*d^-1*e*c^-1*a^-1, b*c*(b*c^-1)^4*b^-1*c^-1,   d*b*c^-1*d^-1*b^-1*e*b^-1*d*c^-1*d*b*e, c*a^-1*d^-1*e*d*e*a*c^-1*d^-1*e*d*e,  ((b^-1*a)^2*b*a)^2, (a*b^-1*(a*b)^2)^2, (b^-1*a^-1)^6,   a*b^-1*a*b*a*d^-1*a^-1*b^-1*a^-1*b*a^-1*d,   b^-1*d^-1*e*d*e*b*e*c^-1*d*e*d^-1*e*c,   d^-1*c^-1*b*c^-1*b^-1*c^-1*d^-2*c*b*c^-1*b^-1*c^-1*d^-1,   (e*(b^-1*a^-1)^2*b*a^-1)^2, (a*b^-1)^2*c*d^-2*b*a*b^-1*c*a^-1*b^-1*c,   (e*(b^-1*c^-1)^2*b^-1*a)^2, (d*e*d^-1*e*a)^3,   c^-1*b^-1*c^-1*e*c^-1*b*(c^-1*e*c*b^-1)^2*c*e,   e*d^-1*e*b^-1*(a*b)^2*a*e*d^-1*e*(a*b)^3,   d*a^-1*e*d^-1*e*a^-1*b^-1*e*b*a*d*e*d^-1*e*a^-1*b*e*b,   c*e*b*a*e*d*e*a*b^-1*c^-1*b^-1*d*c^-1*e*c^-1*b*c^-1*d^-1*e,   e*c^-1*e*b*a*e*d*e*a*b*c*d^-1*b^-1*c^-1*e*c^-1*b^-1*c*d^-1,   c^-1*d*e*b^-1*d*c*e*c*b*c*d*e*b*a^-1*e*c^2*d*e*a^-1*b,   (b^-1*e)^2*c*a^-1*b*a*d*e*d^-1*e*a^-1*b*c*e*a*d*e*d^-1*e*a,   c*e*d*e*c^-1*d*b*a^-1*e*d*e*d^-1*a*d*b*e*d*c*b^-1*e*b*e*d,   b^-1*e*b*(d^-1*e)^2*b*c*b^-1*c*b*c^-1*d^-1*b*d*c*d^-1*e*d*e*b^-1*c*b*c,   b^-1*e*c^-1*b^-1*a*d^-1*e*d*e*a^-1*b*e*c*e*d^-1*e*b^-1*e*d^-1*a^-1*e*(d*e*b)^2*a*e*d^-1*e*d,   a*b*a*b^-1*e*d^-1*e*c^-1*b*a*e*a^-1*d^-2*c^-1*b*c^-1*d*b*e*d*e*c*b^-1*c^-1*e*c^-1*b^-1*c^-1*d^-1*a*b^-1 ]"

# %%
rels_no_bracket = rels_str[1:-1]
rels_no_bracket
# Out:
# ' e^2, a^3, b^-2*c^2, b^4, (b^-1*d)^2, (c*a)^2, (b^-1*d^-1)^2, d^4,   d^-1*b^-2*a*d*a, c*a*e*a^-1*c^-1*e, d^-1*e*d^2*e*d^-1, e*b^2*e*b^-2,   (c*d^-1)^3, (e*a^-1)^3, c^-1*d^-2*a*d^-2*c^-1*a, (d*e)^2*(d^-1*e)^2,   (b^-1*a^-1*b^-1*a)^2, a*c^2*a^-1*e*c^-1*a^-1*c*a^-1*e,   c^-1*d^-1*c^-1*d*e*d^-1*c^-1*e*d*c^-1*e,   b*c*d*c^-1*b*c*b*d^-1*c^-1*d^-1*b^-1*c^-1,   b^-1*c^-1*d^-1*e*d*c^-1*b*c^-1*d^-1*e*d*c^-1, b^3*d*c*d*b^-2*d^-1*c*b^-1*d,   d^-2*c*b^-1*a^-1*b*c^-1*a*b^-1*c^-1*b^-1*a,   d^-1*e*d^-1*a*e*a^-1*d*e*d*a*e*a^-1, d*b^-1*a*d^-1*c*b^-1*a*b*a*c^-1*b*c,   d*e*d^-1*e*a*c*d*e*d^-1*e*c^-1*a^-1, b*c*(b*c^-1)^4*b^-1*c^-1,   d*b*c^-1*d^-1*b^-1*e*b^-1*d*c^-1*d*b*e, c*a^-1*d^-1*e*d*e*a*c^-1*d^-1*e*d*e,  ((b^-1*a)^2*b*a)^2, (a*b^-1*(a*b)^2)^2, (b^-1*a^-1)^6,   a*b^-1*a*b*a*d^-1*a^-1*b^-1*a^-1*b*a^-1*d,   b^-1*d^-1*e*d*e*b*e*c^-1*d*e*d^-1*e*c,   d^-1*c^-1*b*c^-1*b^-1*c^-1*d^-2*c*b*c^-1*b^-1*c^-1*d^-1,   (e*(b^-1*a^-1)^2*b*a^-1)^2, (a*b^-1)^2*c*d^-2*b*a*b^-1*c*a^-1*b^-1*c,   (e*(b^-1*c^-1)^2*b^-1*a)
# ...

# %%
rels_list_with_spaces = rels_no_bracket.split(",")
rels_list_with_spaces
# Out:
# [' e^2',
#  ' a^3',
#  ' b^-2*c^2',
#  ' b^4',
#  ' (b^-1*d)^2',
#  ' (c*a)^2',
#  ' (b^-1*d^-1)^2',
#  ' d^4',
#  '   d^-1*b^-2*a*d*a',
#  ' c*a*e*a^-1*c^-1*e',
#  ' d^-1*e*d^2*e*d^-1',
#  ' e*b^2*e*b^-2',
#  '   (c*d^-1)^3',
#  ' (e*a^-1)^3',
#  ' c^-1*d^-2*a*d^-2*c^-1*a',
#  ' (d*e)^2*(d^-1*e)^2',
#  '   (b^-1*a^-1*b^-1*a)^2',
#  ' a*c^2*a^-1*e*c^-1*a^-1*c*a^-1*e',
#  '   c^-1*d^-1*c^-1*d*e*d^-1*c^-1*e*d*c^-1*e',
#  '   b*c*d*c^-1*b*c*b*d^-1*c^-1*d^-1*b^-1*c^-1',
#  '   b^-1*c^-1*d^-1*e*d*c^-1*b*c^-1*d^-1*e*d*c^-1',
#  ' b^3*d*c*d*b^-2*d^-1*c*b^-1*d',
#  '   d^-2*c*b^-1*a^-1*b*c^-1*a*b^-1*c^-1*b^-1*a',
#  '   d^-1*e*d^-1*a*e*a^-1*d*e*d*a*e*a^-1',
#  ' d*b^-1*a*d^-1*c*b^-1*a*b*a*c^-1*b*c',
#  '   d*e*d^-1*e*a*c*d*e*d^-1*e*c^-1*a^-1',
#  ' b*c*(b*c^-1)^4*b^-1*c^-1',
#  '   d*b*c^-1*d^-1*b^-1*e*b^-1*d*c^-1*d*b*e',
#  ' c*a^-1*d^-1*e*d*e*a*c^-1*d^-1*e*d*e',
#  '  ((b^-1*a)^2*b*a)^2',
#  ' (a*b^-1*(a*b)^2)^2',
#  ' (b^-1*a^-1)^6',
#  '   a*b^-1*a*b*a*d^-1*a^-1*b^-1*a^-1*b*a^-1*d',
# ...

# %%
rels_list = [x.strip() for x in rels_list_with_spaces]
rels_list
# Out:
# ['e^2',
#  'a^3',
#  'b^-2*c^2',
#  'b^4',
#  '(b^-1*d)^2',
#  '(c*a)^2',
#  '(b^-1*d^-1)^2',
#  'd^4',
#  'd^-1*b^-2*a*d*a',
#  'c*a*e*a^-1*c^-1*e',
#  'd^-1*e*d^2*e*d^-1',
#  'e*b^2*e*b^-2',
#  '(c*d^-1)^3',
#  '(e*a^-1)^3',
#  'c^-1*d^-2*a*d^-2*c^-1*a',
#  '(d*e)^2*(d^-1*e)^2',
#  '(b^-1*a^-1*b^-1*a)^2',
#  'a*c^2*a^-1*e*c^-1*a^-1*c*a^-1*e',
#  'c^-1*d^-1*c^-1*d*e*d^-1*c^-1*e*d*c^-1*e',
#  'b*c*d*c^-1*b*c*b*d^-1*c^-1*d^-1*b^-1*c^-1',
#  'b^-1*c^-1*d^-1*e*d*c^-1*b*c^-1*d^-1*e*d*c^-1',
#  'b^3*d*c*d*b^-2*d^-1*c*b^-1*d',
#  'd^-2*c*b^-1*a^-1*b*c^-1*a*b^-1*c^-1*b^-1*a',
#  'd^-1*e*d^-1*a*e*a^-1*d*e*d*a*e*a^-1',
#  'd*b^-1*a*d^-1*c*b^-1*a*b*a*c^-1*b*c',
#  'd*e*d^-1*e*a*c*d*e*d^-1*e*c^-1*a^-1',
#  'b*c*(b*c^-1)^4*b^-1*c^-1',
#  'd*b*c^-1*d^-1*b^-1*e*b^-1*d*c^-1*d*b*e',
#  'c*a^-1*d^-1*e*d*e*a*c^-1*d^-1*e*d*e',
#  '((b^-1*a)^2*b*a)^2',
#  '(a*b^-1*(a*b)^2)^2',
#  '(b^-1*a^-1)^6',
#  'a*b^-1*a*b*a*d^-1*a^-1*b^-1*a^-1*b*a^-1*d',
#  'b^-1*d^-1*e*d*e*b*e*c^-1*d*e*d^-1*e*c',
# ...

# %%
def compose_vals(word):
    powers = dict()

    
    for sym in word:
# Out:
# [['e^2'],
#  ['a^3'],
#  ['b^-2', 'c^2'],
#  ['b^4'],
#  ['(b^-1', 'd)^2'],
#  ['(c', 'a)^2'],
#  ['(b^-1', 'd^-1)^2'],
#  ['d^4'],
#  ['d^-1', 'b^-2', 'a', 'd', 'a'],
#  ['c', 'a', 'e', 'a^-1', 'c^-1', 'e'],
#  ['d^-1', 'e', 'd^2', 'e', 'd^-1'],
#  ['e', 'b^2', 'e', 'b^-2'],
#  ['(c', 'd^-1)^3'],
#  ['(e', 'a^-1)^3'],
#  ['c^-1', 'd^-2', 'a', 'd^-2', 'c^-1', 'a'],
#  ['(d', 'e)^2', '(d^-1', 'e)^2'],
#  ['(b^-1', 'a^-1', 'b^-1', 'a)^2'],
#  ['a', 'c^2', 'a^-1', 'e', 'c^-1', 'a^-1', 'c', 'a^-1', 'e'],
#  ['c^-1', 'd^-1', 'c^-1', 'd', 'e', 'd^-1', 'c^-1', 'e', 'd', 'c^-1', 'e'],
#  ['b',
#   'c',
#   'd',
#   'c^-1',
#   'b',
#   'c',
#   'b',
#   'd^-1',
#   'c^-1',
#   'd^-1',
#   'b^-1',
#   'c^-1'],
#  ['b^-1',
#   'c^-1',
#   'd^-1',
#   'e',
#   'd',
#   'c^-1',
#   'b',
#   'c^-1',
#   'd^-1',
#   'e',
#   'd',
#   'c^-1'],
#  ['b^3', 'd', 'c', 'd', 'b^-2', 'd^-1', 'c', 'b^-1', 'd'],
#  ['d^-2', 'c', 'b^-1', 'a^-1', 'b', 'c^-1', 'a', 'b^-1', 'c^-1', 'b^-1', 'a'],
# ...
